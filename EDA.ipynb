# %%
import pandas as pd

# %%
df_train_split = pd.read_csv('train_split.csv')

df_train_split.columns

len(df_train_split)

df_test_split = pd.read_csv('test_split.csv')
df_test_split.columns
len(df_test_split)
# Out:
# /tmp/ipykernel_17479/2403237533.py:1: DtypeWarning: Columns (19,24,52,55,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_train_split = pd.read_csv('train_split.csv')
# /tmp/ipykernel_17479/2403237533.py:7: DtypeWarning: Columns (52,55,58) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test_split = pd.read_csv('test_split.csv')
# 39867

# %%
df_train_split.describe()
# Out:
#                   id    dormitorios          banos        precio  \
# count  110000.000000  102884.000000  106172.000000  1.099680e+05
# mean    55000.500000       2.939116       2.417070  7.451507e+05
# std     31754.409143       1.262672       6.875272  2.191973e+06
# min         1.000000       0.000000       0.000000  0.000000e+00
# 25%     27500.750000       2.000000       2.000000  2.499000e+05
# 50%     55000.500000       3.000000       2.000000  3.989970e+05
# 75%     82500.250000       4.000000       3.000000  6.500000e+05
# max    110000.000000      91.000000    2204.000000  2.850000e+08
#
#        anio_construccion  codigo_postal       longitud        latitud  \
# count        9003.000000  110000.000000  109666.000000  109666.000000
# mean         2008.608020   33438.614909     -81.700261      27.720004
# std           675.901256     784.872605       1.564072       1.485288
# min             0.000000   32003.000000    -111.477200      24.548346
# ...
